# %% [markdown]
# <a href="https://ondiande.com/contact/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="ONDIA Contact" width="110" height="200" title="This notebook is licensed by ONDIA. Please contact the authorized persons about the conditions under which you can use or share."></a>

# %% [markdown]
# <div style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:200%; text-align:center; border-radius:10px 10px; margin-top:20px; margin-bottom:20px; padding-top:15px; padding-bottom:15px; font-weight:bold;"></div>
#
# <p style="text-align: center;"> <a href="https://ondiande.com/"> <img src="https://i.ibb.co/mvHRT4S/ONDIA-logo.png" width="500" height="200" class="img-fluid" alt="ONDIA LOGO" title="INTELLIGENT & PERSONALIZED SOLUTIONS TO DATA ANALYSIS AND DATA MANAGEMENT ISSUES"> </a> </p>
#
# <div style="background-color:#58B8E4; font-family:newtimeroman; color:#635EA7; font-size:200%; text-align:center; border-radius:10px 10px; margin-top:20px; margin-bottom:20px; padding-top:15px; padding-bottom:15px; font-weight:bold;">
#   Intelligent & Personalized Solutions
# </div>
#
#
# <img src=https://i.ibb.co/HgnTPh9/stats.png width="500" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:300%; text-align:center; border-radius:10px 10px;">Basic Statistics</p>
#
# ![Image_Assignment](https://i.ibb.co/cY9HhF7/bnote-assignment.gif)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:175%; text-align:center; border-radius:10px 10px;">Assignment 02 (Confidence Interval & Hypothesis)</p>

# %% [markdown]
#  ### <span style="color:#49519E">1. Import NumPy, SciPy, Pandas, Matplolib, and Seaborn Libraries.<span>

# %%
import numpy as np
from scipy import stats
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:175%; text-align:center; border-radius:10px 10px;">Confidence Interval</p>

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-1:</p>
#
# + What is the normal body temperature for healthy humans? A random sample of
# 130 healthy human body temperatures provided by Allen Shoemaker yielded 98.25 degrees and standard deviation 0.73 degrees.
#
# - Give a 99% confidence interval for the average body temperature of healthy people.

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First write the given variables:</p>

# %%
sample_mean = 98.25       # Sample mean (x̄)
sample_std_dev = 0.73     # Sample standard deviation (σ)
sample_size = 130         # Sample size (n)
confidence_level = 0.99   # Confidence level (99%,ci)

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Second calculate te standard error of te mean (SEM):</p>

# %% [markdown]
# ![image.png](attachment:09ac8df7-c83d-4fa3-9ad6-c44df1df27d2.png)

# %%
sem = sample_std_dev / np.sqrt(sample_size)

print(f"Standart Error of the Mean: {sem}")
# Out:
# Standart Error of the Mean: 0.06402523540941313

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Third calculate the interval at the given confidence level:</p>

# %%
confi_interval = stats.norm.interval(0.99, loc = sample_mean, scale = sem)
confi_interval
# Out:
# (98.08508192246582, 98.41491807753418)

# %%
# Alternative
moe = 2.58 *sem
ci_upper = sample_mean + moe
ci_lower = sample_mean - moe
print(f"99% Confidence Interval: ({ci_lower:}, {ci_upper:})")
# Out:
# 99% Confidence Interval: (98.08481489264372, 98.41518510735628)

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Last make a decision:</p>

# %% [raw]
# Based on the sample of 130 healthy individuals, we are 99% confident that the true average body temperature of healthy humans lies between 98.08481489264372 and 98.41518510735628.

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-2:</p>
#
# + The administrators for a hospital wished to estimate the average number of days required for inpatient treatment of patients between the ages of 25 and 34. A random sample of 500 hospital patients between these ages produced a mean and standard deviation equal to 5.4 and 3.1 days, respectively.
#
#
# + Construct a 95% confidence interval for the mean length of stay for the population of patients from which the sample was drawn.

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First write the given variables:</p>

# %%
sample_size = 500 # Sample size (n)
sample_mean = 5.4  # Sample mean (x̄)
sample_std = 3.1  # Sample standard deviation (σ)
confidence_level = 0.95  # Confidence level (95%,ci)

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Second calculate te standard error of te mean (SEM):</p>

# %%
sem = sample_std / np.sqrt(sample_size)
print(f"Standart Error of the Mean: {sem}")
# Out:
# Standart Error of the Mean: 0.13863621460498696

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Third calculate the interval at the given confidence level:</p>

# %%
confi_interval = stats.norm.interval(0.95, loc = sample_mean, scale = sem)
confi_interval
# Out:
# (5.12827801242126, 5.67172198757874)

# %%
moe = 1.96 *sem
ci_upper = sample_mean + moe
ci_lower = sample_mean - moe
print(f"95% Confidence Interval: ({ci_lower:.4f}, {ci_upper:.4f})")
# Out:
# 95% Confidence Interval: (5.1283, 5.6717)

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Last make a decision:</p>

# %% [raw]
# According to the 95% confidence interval, the average time to recovery of patients for the sampled patient population is between 5.1283 and 5.6717.

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:175%; text-align:center; border-radius:10px 10px;">Hypothesis Testing</p>

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-3:</p>
#
#   - The hourly wages in a particular industry are normally distributed with mean    $13.20     and
# standard deviation   $2.50. A company in this industry employs 40 workers, paying them an average of $12.20 per hour.
# Can this company be accused of paying substandard wages? Use an α = .01 level test. (Wackerly, Ex.10.18)
#
#
#   - CHECK: statistic: -2.5298221281347035, pvalue= 0.005706018193000826

# %% [markdown]
# ## <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#E9335A; font-size:150%; text-align:left; border-radius:10px 10px;"> REMINDER:</p>
#
# <img src=https://i.ibb.co/G0vg8c2/significance-test-steps.png width="400" height="200">

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First write the given variables:</p>

# %%
pop_mean = 13.20                   # Population mean (µ)
pop_std = 2.50                     # Population standard deviation (σ)
sample_size = 40                   # Sample size (n)
sample_mean = 12.20                # Sample mean (x̄)
alpha = 0.01                       #  α = .01 level test
pvalue = 0.005706018193000826
statistic = 2.5298221281347035

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">1. Stating Null (H0) & Alternative (Ha) Hypotheses:</p>

# %% [markdown]
# **``Stating Null (H0) & Alternative (Ha) Hypotheses:``**
#
#  ``H0:`` The company pays the standard wage (μ = $13.20)
#
#  ``Ha:`` The company pays substandard wages (μ < $13.20)  (One-tailed test)

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">2. Calculating Test Statistics:</p>

# %%
z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
print(f"Test Statistic (z-score): {z_score}")
# Out:
# Test Statistic (z-score): -2.5298221281347035

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">3. Calculaing P-Value:</p>

# %%
p_value = stats.norm.cdf(z_score)
print(f"P-value: {p_value}")
# Out:
# P-value: 0.005706018193000826

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">4. Making a Decision:</p>

# %% [markdown]
# <img src=https://i.ibb.co/NCLKcFs/p-value-reject-area.png width="400" height="200">

# %%
if p_value < alpha:
    print("Decision: Reject the null hypothesis (H0)")
    print("Conclusion: There is sufficient evidence to conclude that the company pays substandard wages.")
else:
    print("Decision: Fail to reject the null hypothesis (H0)")
    print("Conclusion: There is not sufficient evidence to conclude that the company pays substandard wages.")
# Out:
# Decision: Reject the null hypothesis (H0)
# Conclusion: There is sufficient evidence to conclude that the company pays substandard wages.

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-4:</p>
#
# + Shear strength measurements derived from unconfined compression tests for two types of soils gave the results shown in the following document (measurements in tons per square foot). Do the soils appear to differ with respect to average shear strength, at the 1% significance level?
#
#
# + Results for two type of soils
#
#
# + CHECK: statistic: 5.1681473319343345, pvalue= 2.593228732352821e-06

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First Read, Assign Dataset to a DataFrame, and Prepare it for Analysis:</p>

# %%
cd
# Out:
# C:\Users\ilahe

# %%
df0 = pd.read_excel("soil.xlsx")
df0
# Out:
#     Soil1  Soil2
# 0   1.442  1.364
# 1   1.943  1.878
# 2   1.110  1.337
# 3   1.912  1.828
# 4   1.553  1.371
# 5   1.641  1.428
# 6   1.499  1.119
# 7   1.347  1.373
# 8   1.685  1.589
# 9   1.578  1.714
# 10  1.866  1.260
# 11  1.653  1.492
# 12  1.665  1.395
# 13  1.640  1.778
# 14  1.976  1.611
# 15  1.754  1.202
# 16  1.589  1.542
# 17  1.976  1.094
# 18  1.863  1.557
# 19  1.932  1.053
# 20  1.570  1.183
# 21  1.613  1.367
# 22  2.054  1.144
# 23  1.550  1.151
# 24  1.714  1.561
# 25  1.896  1.192
# 26  1.737  1.489
# 27  1.740  1.379
# 28  1.708  1.501
# 29  1.548  1.277
# 30    NaN  1.593
# 31    NaN  1.172
# 32    NaN  1.510
# 33    NaN  1.740
# 34    NaN  1.355

# %%
df = df0.dropna()

# %%
soil1 = df0["Soil1"].dropna()
soil1
# Out:
# 0     1.442
# 1     1.943
# 2     1.110
# 3     1.912
# 4     1.553
# 5     1.641
# 6     1.499
# 7     1.347
# 8     1.685
# 9     1.578
# 10    1.866
# 11    1.653
# 12    1.665
# 13    1.640
# 14    1.976
# 15    1.754
# 16    1.589
# 17    1.976
# 18    1.863
# 19    1.932
# 20    1.570
# 21    1.613
# 22    2.054
# 23    1.550
# 24    1.714
# 25    1.896
# 26    1.737
# 27    1.740
# 28    1.708
# 29    1.548
# Name: Soil1, dtype: float64

# %%
soil2 = df0["Soil2"]
soil2
# Out:
# 0     1.364
# 1     1.878
# 2     1.337
# 3     1.828
# 4     1.371
# 5     1.428
# 6     1.119
# 7     1.373
# 8     1.589
# 9     1.714
# 10    1.260
# 11    1.492
# 12    1.395
# 13    1.778
# 14    1.611
# 15    1.202
# 16    1.542
# 17    1.094
# 18    1.557
# 19    1.053
# 20    1.183
# 21    1.367
# 22    1.144
# 23    1.151
# 24    1.561
# 25    1.192
# 26    1.489
# 27    1.379
# 28    1.501
# 29    1.277
# 30    1.593
# 31    1.172
# 32    1.510
# 33    1.740
# 34    1.355
# Name: Soil2, dtype: float64

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">1. Stating Null (H0) & Alternative (Ha) Hypotheses:</p>

# %% [raw]
# Null Hypothesis (H₀):
# μ₁ = μ₂
# (The two soil types have the same average shear strength.)
#
# Alternative Hypothesis (Hₐ):
# μ₁ ≠ μ₂
# (The two soil types have different average shear strengths.)

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">2. Calculating Test Statistics:</p>

# %%
#  two-sample t-test
test_stat = stats.ttest_ind(soil1, soil2, equal_var=True)  # assuming equal variances
test_stat
# Out:
# TtestResult(statistic=5.1681473319343345, pvalue=2.593228732352821e-06, df=63.0)

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">3. Calculaing P-Value:</p>

# %%
p_val = test_stat.pvalue
p_val
# Out:
# 2.593228732352821e-06

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">4. Making a Decision:</p>

# %% [markdown]
# <img src=https://i.ibb.co/NCLKcFs/p-value-reject-area.png width="400" height="200">

# %%
# given significance level 0.01

alpha = 0.01 # significance level

if p_val < alpha:
    print(f"At the given significance level {alpha}, we reject H₀")
else:
    (f"At the given significance level {alpha}, we fail to reject H₀")
# Out:
# At the given significance level 0.01, we reject H₀

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-5:</p>
#
# + The following dataset is based on data provided by the World Bank
# (https://datacatalog.worldbank.org/dataset/education-statistics). World Bank Edstats.  2015 PISA Test Dataset
#
#
# + Get descriptive statistics (the central tendency, dispersion and shape of a dataset’s distribution) for each continent
# group (AS, EU, AF, NA, SA, OC).
#
#
# + Determine whether there is any difference (on the average) for the math scores among European (EU) and Asian (AS)
# countries (assume normality and equal variances). Draw side-by-side box plots.
#
#
# + CHECK: statistic=0.870055317967983, pvalue=0.38826888111307345

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First Explore the Dataset:</p>
#
# Get descriptive statistics (the central tendency, dispersion and shape of a dataset’s distribution) for each continent group (AS, EU, AF, NA, SA, OC).
#
# Determine whether there is any difference (on the average) for the math scores among European (EU) and Asian (AS) countries (assume normality and equal variances). Draw side-by-side box plots.

# %%
df = pd.read_excel("2015 PISA Test.xlsx")
df
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 0           ALB             EU               63.252933  413.1570  405.2588
# 1           ARE             AS               90.500000  427.4827  433.5423
# 2           ARG             SA               68.043064  409.0333  425.3031
# 3           AUS             OC               84.560519  493.8962  502.9006
# 4           AUT             EU               83.940142  496.7423  484.8656
# ..          ...            ...                     ...       ...       ...
# 65          TUN             AF               48.519836  366.8180  361.0555
# 66          TUR             EU               53.744979  420.4540  428.3351
# 67          URY             SA               64.600000  417.9919  436.5721
# 68          USA            NaN               74.554202  469.6285  496.9351
# 69          VNM             AS               43.500000  494.5183  486.7738
#
#      Science
# 0   427.2250
# 1   436.7311
# 2   432.2262
# 3   509.9939
# 4   495.0375
# ..       ...
# 65  386.4034
# 66  425.4895
# 67  435.3630
# 68  496.2424
# 69  524.6445
#
# [70 rows x 6 columns]

# %%
df.describe().T
# Out:
#                         count        mean        std         min         25%  \
# internet_users_per_100   70.0   71.973099  16.390632   21.976068   60.899020
# Math                     70.0  460.971557  53.327205  327.702000  417.416075
# Reading                  70.0  460.997291  49.502679  346.549000  426.948625
# Science                  70.0  465.439093  48.397254  331.638800  425.923375
#
#                               50%         75%       max
# internet_users_per_100   72.99935   85.026763   98.2000
# Math                    477.60715  500.482925  564.1897
# Reading                 480.19985  499.687475  535.1002
# Science                 475.40005  502.431250  555.5747

# %%
df.shape
# Out:
# (70, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country Code            70 non-null     object
#  1   Continent_Code          65 non-null     object
#  2   internet_users_per_100  70 non-null     float64
#  3   Math                    70 non-null     float64
#  4   Reading                 70 non-null     float64
#  5   Science                 70 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 3.4+ KB

# %%
df["Continent_Code"].value_counts(dropna=False)
# Out:
# Continent_Code
# EU     37
# AS     17
# SA      7
# NaN     5
# OC      2
# AF      2
# Name: count, dtype: int64

# %%
df[df["Continent_Code"].isnull()]
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 8           CAN            NaN               88.470000  515.6474  526.6678
# 13          CRI            NaN               59.762950  400.2534  427.4875
# 18          DOM            NaN               54.215766  327.7020  357.7377
# 45          MEX            NaN               57.431043  408.0235  423.2765
# 68          USA            NaN               74.554202  469.6285  496.9351
#
#      Science
# 8   527.7047
# 13  419.6080
# 18  331.6388
# 45  415.7099
# 68  496.2424

# %%
pd.set_option("display.max_columns",None)

# %%
#Get descriptive statistics (the central tendency, dispersion and shape of a dataset’s distribution) for each continent group (AS, EU, AF, NA, SA, OC).d
df.groupby("Continent_Code").describe()
# Out:
#                internet_users_per_100                                   \
#                                 count       mean        std        min
# Continent_Code
# AF                                2.0  43.359918   7.297226  38.200000
# AS                               17.0  68.455613  21.086060  21.976068
# EU                               37.0  77.274888  12.425773  53.744979
# OC                                2.0  86.391704   2.589686  84.560519
# SA                                7.0  60.180494   9.772455  40.900000
#
#                                                             Math              \
#                       25%        50%        75%        max count        mean
# Continent_Code
# AF              40.779959  43.359918  45.939877  48.519836   2.0  363.212100
# AS              50.300000  74.000000  84.948353  92.884826  17.0  466.216647
# EU              68.632900  76.184000  87.479056  98.200000  37.0  477.981449
# OC              85.476112  86.391704  87.307296  88.222889   2.0  494.559750
# SA              57.116462  64.289000  66.321532  69.198471   7.0  402.887700
#
#                                                                         \
#                       std       min         25%        50%         75%
# Continent_Code
# AF               5.099513  359.6062  361.409150  363.21210  365.015050
# AS              64.356490  380.2590  403.833200  459.81600  531.296100
# EU              35.150403  371.3114  464.040100  489.72870  503.722000
# OC               0.938401  493.8962  494.227975  494.55975  494.891525
# SA              18.128894  377.0695  388.102200  409.03330  417.617650
#
#                          Reading                                               \
#                      max   count        mean        std       min         25%
# Continent_Code
# AF              366.8180     2.0  355.457400   7.916909  349.8593  352.658350
# AS              564.1897    17.0  454.059682  57.048962  346.5490  408.102200
# EU              521.2506    37.0  476.164608  37.720545  351.7415  452.514300
# OC              495.2233     2.0  506.085650   4.504341  502.9006  504.493125
# SA              422.6714     7.0  425.359229  19.709688  397.5414  416.126900
#
#                                                 Science              \
#                       50%         75%       max   count        mean
# Continent_Code
# AF              355.45740  358.256450  361.0555     2.0  381.074250
# AS              433.54230  508.690500  535.1002    17.0  467.945847
# EU              487.25010  499.814600  526.4247    37.0  478.299381
# OC              506.08565  507.678175  509.2707     2.0  511.648700
# SA              425.30310  431.922700  458.5709     7.0  421.747186
#
#                                                                         \
#                       std       min         25%        50%         75%
# Continent_Code
# AF               7.536556  375.7451  378.409675  381.07425  383.738825
# AS              56.671371  386.4854  417.611200  456.48360  523.277400
# EU              34.450616  383.6824  460.774900  490.22500  501.936900
# OC               2.340241  509.9939  510.821300  511.64870  512.476100
# SA              18.470319  396.6836  408.205450  424.59050  433.794600
#
#
#                      max
# Continent_Code
# AF              386.4034
# AS              555.5747
# EU              534.1937
# OC              513.3035
# SA              446.9561

# %%
#Get descriptive statistics (the central tendency, dispersion and shape of a dataset’s distribution) for each continent group (AS, EU, AF, NA, SA, OC).
df.groupby("Continent_Code").describe().T
# Out:
# Continent_Code                        AF          AS          EU          OC  \
# internet_users_per_100 count    2.000000   17.000000   37.000000    2.000000
#                        mean    43.359918   68.455613   77.274888   86.391704
#                        std      7.297226   21.086060   12.425773    2.589686
#                        min     38.200000   21.976068   53.744979   84.560519
#                        25%     40.779959   50.300000   68.632900   85.476112
#                        50%     43.359918   74.000000   76.184000   86.391704
#                        75%     45.939877   84.948353   87.479056   87.307296
#                        max     48.519836   92.884826   98.200000   88.222889
# Math                   count    2.000000   17.000000   37.000000    2.000000
#                        mean   363.212100  466.216647  477.981449  494.559750
#                        std      5.099513   64.356490   35.150403    0.938401
#                        min    359.606200  380.259000  371.311400  493.896200
#                        25%    361.409150  403.833200  464.040100  494.227975
#                        50%    363.212100  459.816000  489.728700  494.559750
#                        75%    365.015050  531.296100  503.722000  494.891525
#                        max    366.818000  564.189700  521.250600  495.223300
# Reading                count    2.000000   17.000000   37.000000    2.000000
#                        mean   355.457400  454.059682  476.164608  506.085650
#                        std      7.916909   57.048962   37.720545    4.504341
#                        min    349.859300  346.549000  351.741500  502.900600
#                        25%    352.658350  408.102200  452.514300  504.493125
#                        50%    355.457400  433.542300  487.250100  506.085650
#                        75%    358.256450  508.690500  499.814600  507.678175
#                        max    361.055500  535.100200  526.424700  509.270700
# Science                count    2.000000   17.000000   37.000000    2.000000
#                        mean   381.074250  467.945847  478.299381  511.648700
#                        std      7.536556   56.671371   34.450616    2.340241
#                        min    375.745100  386.485400  383.682400  509.993900
#                        25%    378.409675  417.611200  460.774900  510.821300
#                        50%    381.074250  456.483600  490.225000  511.648700
#                        75%    383.738825  523.277400  501.936900  512.476100
#                        max    386.403400  555.574700  534.193700  513.303500
#
# Continent_Code                        SA
# internet_users_per_100 count    7.000000
#                        mean    60.180494
#                        std      9.772455
#                        min     40.900000
#                        25%     57.116462
#                        50%     64.289000
#                        75%     66.321532
#                        max     69.198471
# Math                   count    7.000000
#                        mean   402.887700
#                        std     18.128894
#                        min    377.069500
#                        25%    388.102200
#                        50%    409.033300
#                        75%    417.617650
#                        max    422.671400
# Reading                count    7.000000
#                        mean   425.359229
#                        std     19.709688
#                        min    397.541400
#                        25%    416.126900
#                        50%    425.303100
#                        75%    431.922700
#                        max    458.570900
# Science                count    7.000000
#                        mean   421.747186
#                        std     18.470319
#                        min    396.683600
#                        25%    408.205450
#                        50%    424.590500
#                        75%    433.794600
#                        max    446.956100

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Exploring EU & ASIAN Countries:</p>
#
# Determine whether there is any difference (on the average) for the math scores among European (EU) and Asian (AS) countries (assume normality and equal variances). Draw side-by-side box plots. CHECK: statistic=0.870055317967983, pvalue=0.38826888111307345
#
# Avrupa (AB) ve Asya (AS) ülkeleri arasında ``matematik`` puanları için (ortalama olarak) herhangi bir fark olup olmadığını belirleyin (normallik ve eşit varyanslar olduğunu varsayın)

# %%
df.columns
# Out:
# Index(['Country Code', 'Continent_Code', 'internet_users_per_100', 'Math',
#        'Reading', 'Science'],
#       dtype='object')

# %%
eu_as = df[(df["Continent_Code"] == "EU") | (df["Continent_Code"] == "AS")]
eu_as
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 0           ALB             EU               63.252933  413.1570  405.2588
# 1           ARE             AS               90.500000  427.4827  433.5423
# 4           AUT             EU               83.940142  496.7423  484.8656
# 5           BEL             EU               85.052900  506.9844  498.5242
# 6           BGR             EU               56.656300  441.1899  431.7175
# 9           CHE             EU               87.479056  521.2506  492.1982
# 11          CHN             AS               50.300000  531.2961  493.9412
# 14          CYP             EU               71.715900  437.1443  442.8443
# 15          CZE             EU               75.668839  492.3254  487.2501
# 16          DEU             EU               87.589800  505.9713  509.1041
# 17          DNK             EU               96.330500  511.0876  499.8146
# 20          ESP             EU               78.689600  485.8432  495.5764
# 21          EST             EU               88.411812  519.5291  519.1429
# 22          FIN             EU               86.422133  511.0769  526.4247
# 23          FRA             EU               84.694500  492.9204  499.3061
# 24          GBR             EU               92.000300  492.4785  497.9719
# 25          GEO             AS               47.569760  403.8332  401.2881
# 26          GRC             EU               66.835000  453.6299  467.0395
# 27          HKG             AS               84.948353  547.9310  526.6753
# 28          HRV             EU               69.803100  464.0401  486.8632
# 29          HUN             EU               72.834700  476.8309  469.5233
# 30          IDN             AS               21.976068  386.1096  397.2595
# 31          IRL             EU               80.122400  503.7220  520.8148
# 32          ISL             EU               98.200000  488.0332  481.5255
# 33          ISR             AS               77.352090  469.6695  478.9606
# 34          ITA             EU               58.141735  489.7287  484.7580
# 35          JOR             AS               60.114383  380.2590  408.1022
# 36          JPN             AS               91.058028  532.4399  515.9585
# 37          KAZ             AS               72.900000  459.8160  427.1410
# 38          KOR             AS               89.648631  524.1062  517.4367
# 39          LBN             AS               74.000000  396.2497  346.5490
# 40          LTU             EU               71.378000  478.3834  472.4066
# 41          LUX             EU               97.334100  485.7706  481.4391
# 42          LVA             EU               79.200600  482.3051  487.7581
# 43          MAC             AS               77.600132  543.8078  508.6905
# 44          MDA             EU               63.306625  419.6635  416.2293
# 46          MKD             EU               70.380200  371.3114  351.7415
# 47          MLT             EU               76.184000  478.6448  446.6661
# 48          MNE             EU               68.119581  417.9341  426.8845
# 49          MYS             AS               71.064068  446.1098  430.5782
# 50          NLD             EU               91.724138  512.2528  502.9591
# 51          NOR             EU               96.810300  501.7298  513.1912
# 54          POL             EU               67.997000  504.4693  505.6971
# 55          PRT             EU               68.632900  491.6270  498.1289
# 56          QAT             AS               92.884826  402.4007  401.8874
# 57          ROU             EU               55.763200  443.9543  433.6166
# 58          RUS             EU               73.410000  494.0600  494.6278
# 59          SGP             AS               79.012957  564.1897  535.1002
# 60          SVK             EU               77.634700  475.2301  452.5143
# 61          SVN             EU               73.098700  509.9196  505.2159
# 62          SWE             EU               90.610200  493.9181  500.1556
# 63          THA             AS               39.316127  415.4638  409.1301
# 66          TUR             EU               53.744979  420.4540  428.3351
# 69          VNM             AS               43.500000  494.5183  486.7738
#
#      Science
# 0   427.2250
# 1   436.7311
# 4   495.0375
# 5   501.9997
# 6   445.7720
# 9   505.5058
# 11  517.7793
# 14  432.5964
# 15  492.8300
# 16  509.1406
# 17  501.9369
# 20  492.7861
# 21  534.1937
# 22  530.6612
# 23  494.9776
# 24  509.2215
# 25  411.1315
# 26  454.8288
# 27  523.2774
# 28  475.3912
# 29  476.7475
# 30  403.0997
# 31  502.5751
# 32  473.2301
# 33  466.5528
# 34  480.5468
# 35  408.6691
# 36  538.3948
# 37  456.4836
# 38  515.8099
# 39  386.4854
# 40  475.4089
# 41  482.8064
# 42  490.2250
# 43  528.5496
# 44  427.9978
# 46  383.6824
# 47  464.7819
# 48  411.3136
# 49  442.9475
# 50  508.5748
# 51  498.4811
# 54  501.4353
# 55  501.1001
# 56  417.6112
# 57  434.8849
# 58  486.6310
# 59  555.5747
# 60  460.7749
# 61  512.8636
# 62  493.4224
# 63  421.3373
# 66  425.4895
# 69  524.6445

# %%
# let's determine the math scores for European countries
math_eu = eu_as.loc[eu_as.Continent_Code == "EU"]["Math"]
math_eu
# Out:
# 0     413.1570
# 4     496.7423
# 5     506.9844
# 6     441.1899
# 9     521.2506
# 14    437.1443
# 15    492.3254
# 16    505.9713
# 17    511.0876
# 20    485.8432
# 21    519.5291
# 22    511.0769
# 23    492.9204
# 24    492.4785
# 26    453.6299
# 28    464.0401
# 29    476.8309
# 31    503.7220
# 32    488.0332
# 34    489.7287
# 40    478.3834
# 41    485.7706
# 42    482.3051
# 44    419.6635
# 46    371.3114
# 47    478.6448
# 48    417.9341
# 50    512.2528
# 51    501.7298
# 54    504.4693
# 55    491.6270
# 57    443.9543
# 58    494.0600
# 60    475.2301
# 61    509.9196
# 62    493.9181
# 66    420.4540
# Name: Math, dtype: float64

# %%
# let's determine the math scores for Asian countries
math_as = eu_as.loc[eu_as["Continent_Code"]== "AS"]["Math"]
math_as
# Out:
# 1     427.4827
# 11    531.2961
# 25    403.8332
# 27    547.9310
# 30    386.1096
# 33    469.6695
# 35    380.2590
# 36    532.4399
# 37    459.8160
# 38    524.1062
# 39    396.2497
# 43    543.8078
# 49    446.1098
# 56    402.4007
# 59    564.1897
# 63    415.4638
# 69    494.5183
# Name: Math, dtype: float64

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">1. Stating Null (H0) & Alternative (Ha) Hypotheses:</p>

# %% [raw]
# Null Hypothesis (H₀):
# μ₁ = μ₂
#
#
# Alternative Hypothesis (Hₐ):
# μ₁ ≠ μ₂

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">2. Calculating Test Statistics:</p>

# %%
test_stat = stats.ttest_ind(math_eu,math_as)
test_stat
# Out:
# TtestResult(statistic=0.8700553179679789, pvalue=0.38826888111307556, df=52.0)

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">3. Calculaing P-Value:</p>

# %%
p_val = test_stat.pvalue
p_val
# Out:
# 0.38826888111307556

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">4. Making a Decision:</p>

# %% [markdown]
# <img src=https://i.ibb.co/NCLKcFs/p-value-reject-area.png width="400" height="200">

# %%
alpha = 0.05 # significance level 


if pvalue < alpha:
    print(f"At the given significance level {alpha}, Reject H₀: There is a significant difference in math scores between EU and AS.")
else:
    print(f"At the given significance level {alpha},Fail to reject H₀: No significant difference in math scores between EU and AS.")
# Out:
# At the given significance level 0.05, Reject H₀: There is a significant difference in math scores between EU and AS.

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Visualization:</p>

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=eu_as, x ="Continent_Code", y = "Math",showmeans=True, palette ="bright")
plt.title("Math scores by Continent EU vs AS")
plt.ylabel("Math Score")
plt.xlabel("Continent");

# %% [markdown]
# ## <p style="background-color:#8CCED1; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:center; border-radius:10px 10px;">END OF THE ASSIGNMENT-02</p>
#
# # Now. it's time to relax!
#
# ![Image_Assignment](https://i.ibb.co/QF5G0yf/reading-books-1110x600.png)
# [Image Credit](https://booksunlimited.ie/how-to-make-time-for-reading-books-in-a-busy-schedule/)
#
# <p style="text-align: center;"><img src="https://i.ibb.co/mR462SV/ONDIA-courses-logo.jpg" class="img-fluid"
# alt="ONDIA"></p>

# %% [markdown]
# <a href="https://ondiande.com/contact/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="ONDIA Contact" width="110" height="200" title="This notebook is licensed by ONDIA. Please contact the authorized persons about the conditions under which you can use or share."></a>
